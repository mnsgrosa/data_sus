# %%
import pandas as pd
from docling.document_converter import DocumentConverter
from docling.datamodel.base_models import Table
import json

# %%
data = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SRAG/2019/INFLUD19-26-06-2025.csv', sep = ';', low_memory = False)

# %%
data
# Out:
#            NU_NOTIFIC  DT_NOTIFIC  SEM_NOT  DT_SIN_PRI  SEM_PRI SG_UF_NOT  \
# 0        315478195042  2019-01-10        2  2019-01-06        2        MG
# 1        315478195276  2019-01-03        1  2019-01-01        1        SP
# 2        315478207219  2019-01-02        1  2018-12-31        1        PE
# 3        315478211086  2019-01-10        2  2019-01-07        2        SP
# 4        315478212765  2019-01-11        2  2019-01-06        2        PE
# ...               ...         ...      ...         ...      ...       ...
# 48956  31692547426126  2023-08-20       34  2019-11-19       47        CE
# 48957  31706621109902  2019-05-13       20  2019-05-10       19        RJ
# 48958  31706621464126  2019-06-11       24  2019-06-11       24        RJ
# 48959  31709922959685  2019-10-30       44  2019-10-28       44        MT
# 48960  31709925127509  2019-06-01       22  2019-05-27       22        MT
#
#               ID_REGIONA  CO_REGIONA      ID_MUNICIP  CO_MUN_NOT  ... VG_OMS  \
# 0         BELO HORIZONTE      1449.0  BELO HORIZONTE    310620.0  ...    NaN
# 1          GVE I CAPITAL      1331.0       SAO PAULO    355030.0  ...    NaN
# 2                    001      1497.0          RECIFE    261160.0  ...    NaN
# 3      GVE XVII CAMPINAS      1342.0        CAMPINAS    350950.0  ...    NaN
# 4                    004      1499.0         CARUARU    260410.0  ...    NaN
# ...                  ...         ...             ...         ...  ...    ...
# 48956   1 CRES FORTALEZA      1519.0       FORTALEZA    230440.0  ...    NaN
# 48957                NaN         NaN       CABO FRIO    330070.0  ...    NaN
# 48958                NaN         NaN       CABO FRIO    330070.0  ...    NaN
# 48959             CUIABA      1578.0   VARZEA GRANDE    510840.0  ...    NaN
# 48960             CUIABA      1578.0   VARZEA GRANDE    510840.0  ...    NaN
#
#       VG_OMSOUT  VG_LIN  VG_MET  VG_METOUT  VG_DTRES  VG_ENC VG_REINF  \
# 0           NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 1           NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 2           NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 3           NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 4           NaN     NaN     NaN        NaN       NaN     NaN      NaN
# ...         ...     ...     ...        ...       ...     ...      ...
# 48956       NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 48957       NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 48958       NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 48959       NaN     NaN     NaN        NaN       NaN     NaN      NaN
# 48960       NaN     NaN     NaN        NaN       NaN     NaN      NaN
#
#        VG_CODEST REINF
# 0            NaN   NaN
# 1            NaN   NaN
# 2            NaN   NaN
# 3            NaN   NaN
# 4            NaN   NaN
# ...          ...   ...
# 48956        NaN   2.0
# 48957        NaN   2.0
# 48958        NaN   2.0
# 48959        NaN   2.0
# 48960        NaN   2.0
#
# [48961 rows x 194 columns]

# %%
url = "https://opendatasus.saude.gov.br/dataset/39a4995f-4a6e-440f-8c8f-b00c81fae0d0/resource/3135ac9c-2019-4989-a893-2ed50ebd8e68/download/dicionario-de-dados-2019-a-2025.pdf"
document = DocumentConverter().convert(url)
# Out:
# 2025-10-02 11:07:28,780 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-02 11:07:28,784 - INFO - Going to convert document batch...
# 2025-10-02 11:07:28,784 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-02 11:07:28,785 - INFO - Accelerator device: 'cuda:0'
# 2025-10-02 11:07:29,906 - INFO - Accelerator device: 'cuda:0'
# 2025-10-02 11:07:30,982 - INFO - Accelerator device: 'cuda:0'
# 2025-10-02 11:07:31,275 - INFO - Processing document dicionario-de-dados-2019-a-2025.pdf
# 2025-10-02 11:07:48,514 - INFO - Finished converting document dicionario-de-dados-2019-a-2025.pdf in 23.42 sec.

# %%
tables = document.document.export_to_dict().get('tables', [])

# %%
tables[1]
# Out:
# {'self_ref': '#/tables/1',
#  'parent': {'$ref': '#/body'},
#  'children': [],
#  'content_layer': 'body',
#  'label': 'table',
#  'prov': [{'page_no': 2,
#    'bbox': {'l': 37.874229431152344,
#     't': 553.0758895874023,
#     'r': 800.189697265625,
#     'b': 70.84356689453125,
#     'coord_origin': 'BOTTOMLEFT'},
#    'charspan': [0, 0]}],
#  'captions': [],
#  'references': [],
#  'footnotes': [],
#  'data': {'table_cells': [{'bbox': {'l': 362.9722039401531,
#      't': 46.06638361886144,
#      'r': 414.33811840415,
#      'b': 59.17781625688076,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 0,
#     'end_row_offset_idx': 1,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'notificação.',
#     'column_header': True,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 38.19302112609148,
#      't': 64.54181794822216,
#      'r': 128.71527951955795,
#      'b': 77.23949728906155,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 1,
#     'end_row_offset_idx': 2,
#     'start_col_offset_idx': 0,
#     'end_col_offset_idx': 1,
#     'text': '2-Data de 1ºs sintomas',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 190.24721363186836,
#      't': 63.51369547843933,
#      'r': 249.00905883312225,
#      'b': 88.30320057272911,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 1,
#     'end_row_offset_idx': 2,
#     'start_col_offset_idx': 1,
#     'end_col_offset_idx': 2,
#     'text': 'Date DD/MM/AAAA',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 363.88633555173874,
#      't': 63.39873822033405,
#      'r': 433.0888020992279,
#      'b': 91.93431074917316,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 1,
#     'end_row_offset_idx': 2,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'Data de 1º sintomas do caso.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 437.24675142765045,
#      't': 62.196876265108585,
#      'r': 722.7953647375107,
#      'b': 110.37872895598412,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 1,
#     'end_row_offset_idx': 2,
#     'start_col_offset_idx': 4,
#     'end_col_offset_idx': 5,
#     'text': 'Campo Obrigatório Data deve ser <= a data da digitação e data do preenchimento da ficha de notificação',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 724.3976924419403,
#      't': 64.10944348573685,
#      'r': 774.2393085956573,
#      'b': 77.48000937700272,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 1,
#     'end_row_offset_idx': 2,
#     'start_col_offset_idx': 5,
#     'end_col_offset_idx': 6,
#     'text': 'DT_SIN_PRI',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 39.22418263554573,
#      't': 115.52320182323456,
#      'r': 185.60584995150566,
#      'b': 140.27229177951813,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 2,
#     'end_row_offset_idx': 3,
#     'start_col_offset_idx': 0,
#     'end_col_offset_idx': 1,
#     'text': 'Semana Epidemiológica dos Primeiros Sintomas',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 195.23575815558434,
#      't': 114.40940457582474,
#      'r': 242.67232716083527,
#      'b': 126.69506067037582,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 2,
#     'end_row_offset_idx': 3,
#     'start_col_offset_idx': 1,
#     'end_col_offset_idx': 2,
#     'text': 'Varchar2(6)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 363.3506442308426,
#      't': 114.79126909375191,
#      'r': 437.9060044288635,
#      'b': 151.46636566519737,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 2,
#     'end_row_offset_idx': 3,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'Semana Epidemiológica do início dos sintomas.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 438.16779804229736,
#      't': 115.07473528385162,
#      'r': 646.8414707183838,
#      'b': 159.48144096136093,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 2,
#     'end_row_offset_idx': 3,
#     'start_col_offset_idx': 4,
#     'end_col_offset_idx': 5,
#     'text': 'Campo Interno Calculado a partir da data dos Primeiros Sintomas. (SS)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 726.6423773765564,
#      't': 114.45271420478821,
#      'r': 765.3711180686951,
#      'b': 126.47828269004822,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 2,
#     'end_row_offset_idx': 3,
#     'start_col_offset_idx': 5,
#     'end_col_offset_idx': 6,
#     'text': 'SEM_PRI',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 38.64944823086262,
#      't': 164.99348545074463,
#      'r': 58.183880530297756,
#      'b': 176.93326783180237,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 0,
#     'end_col_offset_idx': 1,
#     'text': '3-UF',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 195.48421001434326,
#      't': 164.45634549856186,
#      'r': 245.05549383163452,
#      'b': 177.02645176649094,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 1,
#     'end_col_offset_idx': 2,
#     'text': 'Varchar2(2)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 250.64504182338715,
#      't': 163.7966170310974,
#      'r': 353.15745282173157,
#      'b': 202.71500873565674,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 2,
#     'end_col_offset_idx': 3,
#     'text': 'Tabela com código e siglas das UF padronizados pelo IBGE.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 361.2841143012047,
#      't': 165.7252242565155,
#      'r': 436.6290111541748,
#      'b': 243.43148982524872,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'Unidade Federativa onde está localizada a Unidade que realizou a notificação.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 435.6913866996765,
#      't': 165.37022894620895,
#      'r': 727.2974064350128,
#      'b': 294.5632543563843,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 4,
#     'end_col_offset_idx': 5,
#     'text': 'Campo Obrigatório Se usuário que está digitando a ficha for de nível: \uf0a7 Unidade - o campo é preenchido automaticamente pelo sistema com a UF, município e unidade onde está cadastrado o usuário. \uf0a7 Municipal - o campo é preenchido automaticamente pelo sistema com a UF e município onde está cadastrado o usuário. \uf0a7 Estadual - o campo é preenchido automaticamente pelo sistema com a UF do usuário. \uf0a7 Federal - abre tabela com todas as UF que possuam unidades cadastradas no sistema.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 725.8955570459366,
#      't': 164.70367723703384,
#      'r': 776.4952119588852,
#      'b': 177.2616884112358,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 3,
#     'end_row_offset_idx': 4,
#     'start_col_offset_idx': 5,
#     'end_col_offset_idx': 6,
#     'text': 'SG_UF_NOT',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 38.17745101451874,
#      't': 305.76469016075134,
#      'r': 92.853999838233,
#      'b': 327.27545523643494,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 0,
#     'end_col_offset_idx': 1,
#     'text': '4-Município Código (IBGE)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 193.4112760424614,
#      't': 305.1749322414398,
#      'r': 246.59666520357132,
#      'b': 317.73124837875366,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 1,
#     'end_col_offset_idx': 2,
#     'text': 'Varchar2 (6)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 250.63509511947632,
#      't': 304.4336265325546,
#      'r': 357.73743307590485,
#      'b': 343.0816742181778,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 2,
#     'end_col_offset_idx': 3,
#     'text': 'Tabela com código e nomes dos Municípios padronizados pelo IBGE.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 364.16100537776947,
#      't': 306.01607275009155,
#      'r': 428.9331691265106,
#      'b': 364.0196030139923,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'Município onde está localizada a Unidade que realizou a notificação.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 440.0640758275986,
#      't': 308.0707734823227,
#      'r': 719.6854528188705,
#      'b': 447.43906223773956,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 4,
#     'end_col_offset_idx': 5,
#     'text': 'Campo Obrigatório Preenchendo o nome do município de notificação, o código é preenchido automaticamente, e vice-versa; Se usuário que está digitando a ficha for de nível: \uf0a7 Unidade - o campo é preenchido automaticamente pelo sistema com o Município onde está localizada a unidade de notificação. \uf0a7 Municipal - o campo é preenchido automaticamente pelo sistema com o município do usuário. \uf0a7 Estadual ou Federal - abre tabela com todos os municípios da UF selecionada no campo 3 que possuam unidades cadastradas no sistema.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 726.669810295105,
#      't': 305.0005158185959,
#      'r': 792.4582183361053,
#      'b': 328.413112282753,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 4,
#     'end_row_offset_idx': 5,
#     'start_col_offset_idx': 5,
#     'end_col_offset_idx': 6,
#     'text': 'ID_MUNICIP OU CO_MUN_NOT',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 37.377615660429,
#      't': 452.67531847953796,
#      'r': 168.54667365550995,
#      'b': 477.48083305358887,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 0,
#     'end_col_offset_idx': 1,
#     'text': 'Regional de Saúde de Notificação Código (IBGE)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 194.8406718969345,
#      't': 453.7651697397232,
#      'r': 245.41021418571472,
#      'b': 466.4113515615463,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 1,
#     'end_col_offset_idx': 2,
#     'text': 'Varchar2 (6)',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 250.7760294675827,
#      't': 454.0922831296921,
#      'r': 361.32637643814087,
#      'b': 499.11493360996246,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 2,
#     'end_col_offset_idx': 3,
#     'text': 'Tabela com código e nomes das Regionais de Saúde dos municípios de notificação padronizados pelo IBGE.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 362.59376364946365,
#      't': 453.850754737854,
#      'r': 434.55410146713257,
#      'b': 511.84377002716064,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 3,
#     'end_col_offset_idx': 4,
#     'text': 'Regional de Saúde onde está localizado o Município realizou a notificação.',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 437.6054232120514,
#      't': 455.9283241033554,
#      'r': 699.7431290149689,
#      'b': 518.5326441526413,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 4,
#     'end_col_offset_idx': 5,
#     'text': 'Campo Interno Preenchendo o nome da regional de saúde de notificação, o código é preenchido automaticamente, e vice-versa; Se usuário que está digitando a ficha for de nível:',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False},
#    {'bbox': {'l': 725.6125528812408,
#      't': 452.6957451105118,
#      'r': 795.6264479160309,
#      'b': 476.384086728096,
#      'coord_origin': 'TOPLEFT'},
#     'row_span': 1,
#     'col_span': 1,
#     'start_row_offset_idx': 5,
#     'end_row_offset_idx': 6,
#     'start_col_offset_idx': 5,
#     'end_col_offset_idx': 6,
#     'text': 'ID_REGIONA OU CO_REGIONA',
#     'column_header': False,
#     'row_header': False,
#     'row_section': False,
#     'fillable': False}],
#   'num_rows': 6,
#   'num_cols': 6,
#   'grid': [[{'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 362.9722039401531,
#       't': 46.06638361886144,
#       'r': 414.33811840415,
#       'b': 59.17781625688076,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'notificação.',
#      'column_header': True,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 0,
#      'end_row_offset_idx': 1,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}],
#    [{'bbox': {'l': 38.19302112609148,
#       't': 64.54181794822216,
#       'r': 128.71527951955795,
#       'b': 77.23949728906155,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': '2-Data de 1ºs sintomas',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 190.24721363186836,
#       't': 63.51369547843933,
#       'r': 249.00905883312225,
#       'b': 88.30320057272911,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': 'Date DD/MM/AAAA',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 363.88633555173874,
#       't': 63.39873822033405,
#       'r': 433.0888020992279,
#       'b': 91.93431074917316,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'Data de 1º sintomas do caso.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 437.24675142765045,
#       't': 62.196876265108585,
#       'r': 722.7953647375107,
#       'b': 110.37872895598412,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': 'Campo Obrigatório Data deve ser <= a data da digitação e data do preenchimento da ficha de notificação',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 724.3976924419403,
#       't': 64.10944348573685,
#       'r': 774.2393085956573,
#       'b': 77.48000937700272,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 1,
#      'end_row_offset_idx': 2,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': 'DT_SIN_PRI',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}],
#    [{'bbox': {'l': 39.22418263554573,
#       't': 115.52320182323456,
#       'r': 185.60584995150566,
#       'b': 140.27229177951813,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': 'Semana Epidemiológica dos Primeiros Sintomas',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 195.23575815558434,
#       't': 114.40940457582474,
#       'r': 242.67232716083527,
#       'b': 126.69506067037582,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': 'Varchar2(6)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': '',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 363.3506442308426,
#       't': 114.79126909375191,
#       'r': 437.9060044288635,
#       'b': 151.46636566519737,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'Semana Epidemiológica do início dos sintomas.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 438.16779804229736,
#       't': 115.07473528385162,
#       'r': 646.8414707183838,
#       'b': 159.48144096136093,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': 'Campo Interno Calculado a partir da data dos Primeiros Sintomas. (SS)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 726.6423773765564,
#       't': 114.45271420478821,
#       'r': 765.3711180686951,
#       'b': 126.47828269004822,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 2,
#      'end_row_offset_idx': 3,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': 'SEM_PRI',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}],
#    [{'bbox': {'l': 38.64944823086262,
#       't': 164.99348545074463,
#       'r': 58.183880530297756,
#       'b': 176.93326783180237,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': '3-UF',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 195.48421001434326,
#       't': 164.45634549856186,
#       'r': 245.05549383163452,
#       'b': 177.02645176649094,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': 'Varchar2(2)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 250.64504182338715,
#       't': 163.7966170310974,
#       'r': 353.15745282173157,
#       'b': 202.71500873565674,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': 'Tabela com código e siglas das UF padronizados pelo IBGE.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 361.2841143012047,
#       't': 165.7252242565155,
#       'r': 436.6290111541748,
#       'b': 243.43148982524872,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'Unidade Federativa onde está localizada a Unidade que realizou a notificação.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 435.6913866996765,
#       't': 165.37022894620895,
#       'r': 727.2974064350128,
#       'b': 294.5632543563843,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': 'Campo Obrigatório Se usuário que está digitando a ficha for de nível: \uf0a7 Unidade - o campo é preenchido automaticamente pelo sistema com a UF, município e unidade onde está cadastrado o usuário. \uf0a7 Municipal - o campo é preenchido automaticamente pelo sistema com a UF e município onde está cadastrado o usuário. \uf0a7 Estadual - o campo é preenchido automaticamente pelo sistema com a UF do usuário. \uf0a7 Federal - abre tabela com todas as UF que possuam unidades cadastradas no sistema.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 725.8955570459366,
#       't': 164.70367723703384,
#       'r': 776.4952119588852,
#       'b': 177.2616884112358,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 3,
#      'end_row_offset_idx': 4,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': 'SG_UF_NOT',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}],
#    [{'bbox': {'l': 38.17745101451874,
#       't': 305.76469016075134,
#       'r': 92.853999838233,
#       'b': 327.27545523643494,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': '4-Município Código (IBGE)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 193.4112760424614,
#       't': 305.1749322414398,
#       'r': 246.59666520357132,
#       'b': 317.73124837875366,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': 'Varchar2 (6)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 250.63509511947632,
#       't': 304.4336265325546,
#       'r': 357.73743307590485,
#       'b': 343.0816742181778,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': 'Tabela com código e nomes dos Municípios padronizados pelo IBGE.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 364.16100537776947,
#       't': 306.01607275009155,
#       'r': 428.9331691265106,
#       'b': 364.0196030139923,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'Município onde está localizada a Unidade que realizou a notificação.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 440.0640758275986,
#       't': 308.0707734823227,
#       'r': 719.6854528188705,
#       'b': 447.43906223773956,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': 'Campo Obrigatório Preenchendo o nome do município de notificação, o código é preenchido automaticamente, e vice-versa; Se usuário que está digitando a ficha for de nível: \uf0a7 Unidade - o campo é preenchido automaticamente pelo sistema com o Município onde está localizada a unidade de notificação. \uf0a7 Municipal - o campo é preenchido automaticamente pelo sistema com o município do usuário. \uf0a7 Estadual ou Federal - abre tabela com todos os municípios da UF selecionada no campo 3 que possuam unidades cadastradas no sistema.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 726.669810295105,
#       't': 305.0005158185959,
#       'r': 792.4582183361053,
#       'b': 328.413112282753,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 4,
#      'end_row_offset_idx': 5,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': 'ID_MUNICIP OU CO_MUN_NOT',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}],
#    [{'bbox': {'l': 37.377615660429,
#       't': 452.67531847953796,
#       'r': 168.54667365550995,
#       'b': 477.48083305358887,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 0,
#      'end_col_offset_idx': 1,
#      'text': 'Regional de Saúde de Notificação Código (IBGE)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 194.8406718969345,
#       't': 453.7651697397232,
#       'r': 245.41021418571472,
#       'b': 466.4113515615463,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 1,
#      'end_col_offset_idx': 2,
#      'text': 'Varchar2 (6)',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 250.7760294675827,
#       't': 454.0922831296921,
#       'r': 361.32637643814087,
#       'b': 499.11493360996246,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 2,
#      'end_col_offset_idx': 3,
#      'text': 'Tabela com código e nomes das Regionais de Saúde dos municípios de notificação padronizados pelo IBGE.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 362.59376364946365,
#       't': 453.850754737854,
#       'r': 434.55410146713257,
#       'b': 511.84377002716064,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 3,
#      'end_col_offset_idx': 4,
#      'text': 'Regional de Saúde onde está localizado o Município realizou a notificação.',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 437.6054232120514,
#       't': 455.9283241033554,
#       'r': 699.7431290149689,
#       'b': 518.5326441526413,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 4,
#      'end_col_offset_idx': 5,
#      'text': 'Campo Interno Preenchendo o nome da regional de saúde de notificação, o código é preenchido automaticamente, e vice-versa; Se usuário que está digitando a ficha for de nível:',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False},
#     {'bbox': {'l': 725.6125528812408,
#       't': 452.6957451105118,
#       'r': 795.6264479160309,
#       'b': 476.384086728096,
#       'coord_origin': 'TOPLEFT'},
#      'row_span': 1,
#      'col_span': 1,
#      'start_row_offset_idx': 5,
#      'end_row_offset_idx': 6,
#      'start_col_offset_idx': 5,
#      'end_col_offset_idx': 6,
#      'text': 'ID_REGIONA OU CO_REGIONA',
#      'column_header': False,
#      'row_header': False,
#      'row_section': False,
#      'fillable': False}]]},
#  'annotations': []}

# %%
df
# Out:
#        self_ref              parent children content_layer  label  \
# 0    #/tables/0  {'$ref': '#/body'}       []          body  table
# 1    #/tables/1  {'$ref': '#/body'}       []          body  table
# 2    #/tables/2  {'$ref': '#/body'}       []          body  table
# 3    #/tables/3  {'$ref': '#/body'}       []          body  table
# 4    #/tables/4  {'$ref': '#/body'}       []          body  table
# 5    #/tables/5  {'$ref': '#/body'}       []          body  table
# 6    #/tables/6  {'$ref': '#/body'}       []          body  table
# 7    #/tables/7  {'$ref': '#/body'}       []          body  table
# 8    #/tables/8  {'$ref': '#/body'}       []          body  table
# 9    #/tables/9  {'$ref': '#/body'}       []          body  table
# 10  #/tables/10  {'$ref': '#/body'}       []          body  table
# 11  #/tables/11  {'$ref': '#/body'}       []          body  table
# 12  #/tables/12  {'$ref': '#/body'}       []          body  table
# 13  #/tables/13  {'$ref': '#/body'}       []          body  table
# 14  #/tables/14  {'$ref': '#/body'}       []          body  table
# 15  #/tables/15  {'$ref': '#/body'}       []          body  table
# 16  #/tables/16  {'$ref': '#/body'}       []          body  table
# 17  #/tables/17  {'$ref': '#/body'}       []          body  table
# 18  #/tables/18  {'$ref': '#/body'}       []          body  table
# 19  #/tables/19  {'$ref': '#/body'}       []          body  table
# 20  #/tables/20  {'$ref': '#/body'}       []          body  table
# 21  #/tables/21  {'$ref': '#/body'}       []          body  table
# 22  #/tables/22  {'$ref': '#/body'}       []          body  table
# 23  #/tables/23  {'$ref': '#/body'}       []          body  table
# 24  #/tables/24  {'$ref': '#/body'}       []          body  table
# 25  #/tables/25  {'$ref': '#/body'}       []          body  table
# 26  #/tables/26  {'$ref': '#/body'}       []          body  table
# 27  #/tables/27  {'$ref': '#/body'}       []          body  table
#
#                                                  prov captions references  \
# 0   [{'page_no': 1, 'bbox': {'l': 37.4224472045898...       []         []
# 1   [{'page_no': 2, 'bbox': {'l': 37.8742294311523...       []         []
# 2   [{'page_no': 3, 'bbox': {'l': 37.4692955017089...       []         []
# 3   [{'page_no': 4, 'bbox': {'l': 37.3717308044433...       []         []
# 4   [{'page_no': 5, 'bbox': {'l': 37.6081123352050...       []         []
# 5   [{'page_no': 6, 'bbox': {'l': 37.7849235534668...       []         []
# 6   [{'page_no': 7, 'bbox': {'l': 37.6241226196289...       []         []
# 7   [{'page_no': 8, 'bbox': {'l': 37.8380470275878...       []         []
# 8   [{'page_no': 9, 'bbox': {'l': 37.8929252624511...       []         []
# 9   [{'page_no': 10, 'bbox': {'l': 37.673404693603...       []         []
# 10  [{'page_no': 11, 'bbox': {'l': 37.862663269042...       []         []
# 11  [{'page_no': 12, 'bbox': {'l': 37.569068908691...       []         []
# 12  [{'page_no': 13, 'bbox': {'l': 37.726654052734...       []         []
# 13  [{'page_no': 14, 'bbox': {'l': 37.6484375, 't'...       []         []
# 14  [{'page_no': 15, 'bbox': {'l': 37.482822418212...       []         []
# 15  [{'page_no': 16, 'bbox': {'l': 37.739227294921...       []         []
# 16  [{'page_no': 17, 'bbox': {'l': 37.658702850341...       []         []
# 17  [{'page_no': 18, 'bbox': {'l': 37.740203857421...       []         []
# 18  [{'page_no': 19, 'bbox': {'l': 37.640083312988...       []         []
# 19  [{'page_no': 20, 'bbox': {'l': 37.861358642578...       []         []
# 20  [{'page_no': 21, 'bbox': {'l': 38.204761505126...       []         []
# 21  [{'page_no': 22, 'bbox': {'l': 38.130008697509...       []         []
# 22  [{'page_no': 23, 'bbox': {'l': 37.634761810302...       []         []
# 23  [{'page_no': 24, 'bbox': {'l': 37.550624847412...       []         []
# 24  [{'page_no': 25, 'bbox': {'l': 37.848834991455...       []         []
# 25  [{'page_no': 26, 'bbox': {'l': 37.717823028564...       []         []
# 26  [{'page_no': 27, 'bbox': {'l': 37.371028900146...       []         []
# 27  [{'page_no': 28, 'bbox': {'l': 37.630798339843...       []         []
#
#    footnotes                                               data annotations
# 0         []  {'table_cells': [{'bbox': {'l': 42.0, 't': 294...          []
# 1         []  {'table_cells': [{'bbox': {'l': 362.9722039401...          []
# 2         []  {'table_cells': [{'bbox': {'l': 439.5307325124...          []
# 3         []  {'table_cells': [{'bbox': {'l': 252.2920472323...          []
# 4         []  {'table_cells': [{'bbox': {'l': 253.94, 't': 4...          []
# 5         []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 6         []  {'table_cells': [{'bbox': {'l': 364.85, 't': 4...          []
# 7         []  {'table_cells': [{'bbox': {'l': 253.94, 't': 4...          []
# 8         []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 9         []  {'table_cells': [{'bbox': {'l': 253.94, 't': 4...          []
# 10        []  {'table_cells': [{'bbox': {'l': 444.2628111839...          []
# 11        []  {'table_cells': [{'bbox': {'l': 362.6413851976...          []
# 12        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 13        []  {'table_cells': [{'bbox': {'l': 38.21758982539...          []
# 14        []  {'table_cells': [{'bbox': {'l': 364.85, 't': 4...          []
# 15        []  {'table_cells': [{'bbox': {'l': 38.35700264573...          []
# 16        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 17        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 18        []  {'table_cells': [{'bbox': {'l': 365.1253133416...          []
# 19        []  {'table_cells': [{'bbox': {'l': 440.4093490839...          []
# 20        []  {'table_cells': [{'bbox': {'l': 38.44078034907...          []
# 21        []  {'table_cells': [{'bbox': {'l': 364.2429180741...          []
# 22        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 23        []  {'table_cells': [{'bbox': {'l': 364.85, 't': 4...          []
# 24        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 25        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 26        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []
# 27        []  {'table_cells': [{'bbox': {'l': 42.0, 't': 49....          []

# %%
json.dump(tables[0]['prov'], open('table_idx_0.json', 'w'))

# %%
json.dump(tables[0]['data'], open('table_idx_0_data.json', 'w'))

# %%
json.dump(tables[0].get('table_cells'), open('table.json', 'w'))

# %%
for item in tables[0]['data']['table_cells']:
    if 'text' in item:
        print(item['text'])
# Out:
# Nome do campo
# Tipo
# Categoria
# Descrição
# Características
# DBF
# Nº
# Varchar2(12)
# Número do registro
# Campo Interno Número sequencial gerado automaticamente pelo sistema. Utilizar o padrão: 320120000123 Dígito 1: caracteriza o tipo da ficha (1=SG, 2=SRAG-UTI e 3-SRAG Hospitalizado). Dígitos 2 a 12: número sequencial gerado automaticamente pelo sistema.
# NU_NOTIFIC
# 1-Data do preenchimento da ficha de notificação
# Date DD/MM/AAAA
# Data de preenchimento da ficha de notificação.
# Campo Obrigatório Data deve ser <= a data da digitação.
# DT_NOTIFIC
# Semana Epidemiológica do preenchimento da ficha de notificação
# Varchar2(6)
# Semana Epidemiológica do preenchimento da ficha de
# Campo Interno Calculado a partir da data dos Primeiros Sintomas. (SS)
# SEM_NOT

# %%
colunas = []
caracteristicas = []
tipos = []

tipos_colunas = ['varchar', 'date', 'number']

for table in tables:
    for conteudo in table['data']['table_cells']:
        texto = conteudo.get('text', '')
        if '_' in texto:
            colunas.append(texto)
        elif texto.lower() in tipos_colunas:
            tipos.append(texto)
        elif 'campo' in texto.lower():
            # caracteristicas.append(texto)

# %%
infos
# Out:
# [{'nome_do_campo': 'Nº',
#   'tipo': 'Varchar2(12)',
#   'descricao': 'Número do registro',
#   'caracteristicas': 'Campo Interno Número sequencial gerado automaticamente pelo sistema. Utilizar o padrão: 320120000123 Dígito 1: caracteriza o tipo da ficha (1=SG, 2=SRAG-UTI e 3-SRAG Hospitalizado). Dígitos 2 a 12: número sequencial gerado automaticamente pelo sistema.',
#   'coluna_csv': 'NU_NOTIFIC'},
#  {'nome_do_campo': '1-Data do preenchimento da ficha de notificação',
#   'tipo': 'Date DD/MM/AAAA',
#   'descricao': 'Data de preenchimento da ficha de notificação.',
#   'caracteristicas': 'Campo Obrigatório Data deve ser <= a data da digitação.',
#   'coluna_csv': 'DT_NOTIFIC'},
#  {'nome_do_campo': 'Semana Epidemiológica do preenchimento da ficha de notificação',
#   'tipo': 'Varchar2(6)',
#   'descricao': 'Semana Epidemiológica do preenchimento da ficha de',
#   'caracteristicas': 'Campo Interno Calculado a partir da data dos Primeiros Sintomas. (SS)',
#   'coluna_csv': 'SEM_NOT'}]

# %%
field_def = {}

for element, _level in document.document.iterate_items():

# %%
import pdfplumber
import httpx
from io import BytesIO

# %%
response = httpx.get(url, timeout = 3000000)
pdf = pdfplumber.open(BytesIO(response.content))
page = pdf.pages[0]
# Out:
# 2025-10-02 11:45:59,140 - INFO - HTTP Request: GET https://opendatasus.saude.gov.br/dataset/39a4995f-4a6e-440f-8c8f-b00c81fae0d0/resource/3135ac9c-2019-4989-a893-2ed50ebd8e68/download/dicionario-de-dados-2019-a-2025.pdf "HTTP/1.1 200 OK"

# %%
len(pdf.pages)
# Out:
# 28
